# %% [markdown]
# ![image.png](attachment:bd92df81-ab37-408f-bede-69ee6d48c185.png)

# %%
9+9
# Out:
# 18

# %%
9+9-(10*3)-3
# Out:
# -15

# %%
9+9-10*3-3
# Out:
# -15

# %%
9+9-(10-3)+3
# Out:
# 14

# %%
9+9-10-3+3
# Out:
# 8

# %%
10-5
# Out:
# 5

# %%
10*2
# Out:
# 20

# %%
10**2
# Out:
# 100

# %%
10/5 #float division
# Out:
# 2.0

# %%
10//5 #int sivision
# Out:
# 2

# %%
10%5
# Out:
# 0

# %%
15/6
# Out:
# 2.5

# %%
15%6#modulos
# Out:
# 3

# %%
5^2
# Out:
# 7

# %% [markdown]
# #assignment opereator

# %%
x = 10
x
#x is obj , variable , identifier
# Out:
# 10

# %%
x+2
# Out:
# 12

# %%
x+=2
x
# Out:
# 12

# %%
x+=2
x
# Out:
# 14

# %%
x+=2 #incremental 
x
# Out:
# 16

# %%
x-=2
x
# Out:
# 14

# %%
x-=2
x
# Out:
# 12

# %%
x*=2 #doubt
x
# Out:
# 24

# %%
x*=2
x
# Out:
# 48

# %%
x/=2
x
# Out:
# 48.0

# %%
x
# Out:
# 48.0

# %%
x//=2
x
# Out:
# 24.0

# %% [markdown]
# # unary operator

# %%
n = 7
n
# Out:
# 7

# %%
m=-n
m
# Out:
# -7
